# %%
import nltk
import numpy as np
import string
import pandas as pd
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
try:
    nltk.data.find('corpora/stopwords')
except LookupError:
    nltk.download('stopwords')

# %%
#read textbook data
df = pd.read_excel('textBooksData.xlsx')
df
# Out:
#      book-id                                              title  \
# 0          1           University Physics - Volume 1 (OpenStax)
# 1          2         Conservation Biology in Sub-Saharan Africa
# 2          3                             Psychology of Language
# 3          4  Adult Literacy Fundamental Mathematics: Book 1...
# 4          5           Introduction to Drafting and AutoCAD 2D
# ..       ...                                                ...
# 377      378                    Understanding Media and Culture
# 378      379                           Learning to Learn Online
# 379      380  Building a Competitive First Nation Investment...
# 380      381  Complexités, Capacités, Communautés: Changer l...
# 381      382  Discover Psychology 2.0: A Brief Introductory ...
#
#                             genre  \
# 0    Biological/Physical Sciences
# 1    Biological/Physical Sciences
# 2                          Others
# 3                          Others
# ...

# %%
def preprocessing(doc): 
    # use the English stopwords provided by NLTK
    stop_words = stopwords.words('english')
    # get a Stemmer to convert words to root forms
    stemmer = nltk.stem.PorterStemmer()
    # map every punctuation found in string.punctuation
    # to an empty character (essentially removing them
    # from our corpus)
    punc = str.maketrans('','', string.punctuation)
    doc_no_punc = doc.translate(punc).lower()
    return doc_no_punc
temp = df['combined-text'].apply(preprocessing)
temp
# temp = df.apply(lambda row : preprocessing(df['combined-text']), axis = 1)
# Out:
# 0      university physics  volume 1 openstax universi...
# 1      conservation biology in subsaharan africa easy...
# 2      psychology of language in this textbook studen...
# 3      adult literacy fundamental mathematics book 1 ...
# 4      introduction to drafting and autocad 2d  intro...
#                              ...
# 377    understanding media and culture this book’s ti...
# 378    learning to learn online learning to learn onl...
# 379    building a competitive first nation investment...
# 380    complexités capacités communautés changer le d...
# 381    discover psychology 20 a brief introductory te...
# Name: combined-text, Length: 382, dtype: object

# %%
df['preprocessed'] = temp
df
# Out:
#      book-id                                              title  \
# 0          1           University Physics - Volume 1 (OpenStax)
# 1          2         Conservation Biology in Sub-Saharan Africa
# 2          3                             Psychology of Language
# 3          4  Adult Literacy Fundamental Mathematics: Book 1...
# 4          5           Introduction to Drafting and AutoCAD 2D
# ..       ...                                                ...
# 377      378                    Understanding Media and Culture
# 378      379                           Learning to Learn Online
# 379      380  Building a Competitive First Nation Investment...
# 380      381  Complexités, Capacités, Communautés: Changer l...
# 381      382  Discover Psychology 2.0: A Brief Introductory ...
#
#                             genre  \
# 0    Biological/Physical Sciences
# 1    Biological/Physical Sciences
# 2                          Others
# 3                          Others
# ...

# %%
df.to_excel('textBooksDataPreprocessed.xlsx')
